# %% [markdown]
# ### Kafka through the years: A computational text analysis

# %% [markdown]
# As a researcher with a background in literary studies, computational methods are an exciting possibility to gain insights into larger corpora of texts, as opposed to the traditional close reading of only a few. For the scope of this project, I'll be limiting myself to a few texts only, but hope to gain the skills to execute bigger analyses in the future.
#
# In this project, we'll be looking at a corpus works by the world-famous author Franz Kafka. While Kafka's writing is konwn to be surrealistic, many people interpret his works as reflective of his personal experiences and psyche. This project aims to answer the following questions:
#
# - What topics did Kafka write about most often? Do they change throughout the years?
# - What sentiments do his texts show? Again, do they change throughout the years?
# - What references to specific entities like organizations, places and events – real or fictional – can be found?
#
# This project hopes to gain insight into the evolution of Kafka's writing and possible connections to his personal experiences by using computational methods to make exploring several of his works at once possible.

# %%
# !pip install -U -q gensim mpld3 python-Levenshtein pyldavis
# !pip install wordcloud
# !pip install textblob

# %%
# !pip install spacy

# %%
# !pip install 'pydantic< 2.0'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import re
import os
import codecs
import string

import gensim
from gensim.test.utils import common_corpus, common_dictionary, get_tmpfile

import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %% [markdown]
# We'll be working with a corpus of 12 works by Franz Kafka, and doing some NLP with the whole corpus as well as focusing on a few singular ones:
# - "Amerika" ("Amerika", written between 1911-1914),
# - "Die Verwandlung" ("The Metamorphosis", written 1912),
# - "In der Strafkolonie" ("In the Penal Colony", written 1914),
# - "Der Prozess" ("The Trial", written 1914-1915),
# - "Das Schloss" ("The Castle", written 1922)
# - "Der Bau" ("The Burrow", written 1923-1924)

# %% [markdown]
# #### Let's import the data and clean it! We'll be importing each file separately, so we can easily perform NLP on the individual texts later.

# %%
#downloading models and datasets needed for data cleaning
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /Users/Clara/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/Clara/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/Clara/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#defining a cleaning function:
import spacy
from spacy.lang.de.stop_words import STOP_WORDS
import string

# Load the German spaCy model
nlp = spacy.load('de_core_news_sm')

def clean_text(file_path):
    # Opening file and specifying encoding
    with open(file_path, 'r', encoding='ISO-8859-1') as file:
        text = file.read()

    #removing quotation marks
    text = text.replace('»', '').replace('«', '')

    #removing special characters and numbers
    text = text.translate(str.maketrans('', '', string.punctuation + string.digits))
    
    #lowercasing
    text = text.lower()

    #processing text with spaCy (needed to support lemmatization for german text data)
    doc = nlp(text)

    #lemmatization and removing stopwords
    lemmatized_tokens = [token.lemma_ for token in doc if token.text not in STOP_WORDS]
    
    #putting tokens back into a string
    cleaned_text =  ' '.join(lemmatized_tokens)
    
    return cleaned_text

#let's try it on one of the texts:
the_judgement = clean_text('data/Das_Urteil.txt')
print(the_judgement)
# Out:
# Fräulein Felice b
#
#
#
#  Sonntagvormittag schön Frühjahr Georg Bendemann jung Kaufmann sitzen Privatzimmer Stock niedrig leichtgebaut Haus entlang Flusses lang Reihe fast Höhe Färbung unterscheiden hinzogen Brief Ausland befindenden Jugendfreund beenden verschließen spielerisch Langsamkeit Ellbogen Schreibtisch stützen Fenster Fluß Brücke anhöh Ufer schwach Grün
#
#  dachen Freund Fortkommen Hause unzufrieden Rußland förmlich flüchten betreiben Geschäft Petersburg anfangs anlassen lang stocken scheinen Freund selten werdend Besuch klagen arbeiten Fremde nutzlos fremdartig Vollbart verdecken kinderjahren wohlbekannt Gesicht gelb Hautfarbe entwickelnd Krankheit hinzudeuten scheinen erzählen Verbindung dortig Kolonie Landsleute fast gesellschaftlich Verkehr einheimisch Familie richten endgültig Junggesellentum
#
#  Manne schreiben offenbar verrennen bedauern helfen raten Hause Existenz hierher verlegen alt freundschaftlich Beziehung aufnehmen   wofür Hindernis bestehen   übrig Hilfe Freund vertrauen bedeuten anderer gleichzeitig schonend desto kränkend bisherig Versuch mißlungen ablassen sollen zurückkehren zurückgekehrt Auge anstaunen lassen müssen Freund verstehen alt Kind erfolgreich Haus geblieben Freund einfach folgen sicher Plage antun müssen Zweck gelingen Hause bringen   Verhältnis Heimat verstünd   bleiben trotz Fremde verbittern ratschlag Freund Stück entfremden folgen Rat   Absicht Tatsach   niedergedrückt fände Freund zurecht litte Beschämung Heimat Freund bleiben Fremde umständ denken tatsächlich vorwärts bringen
#
#  Grund brieflich Verbindung aufrecht erhalten eigentlich Mitteilung scheu entferntester bekannten Freund Heimat erklären notdürftig Unsicherheit politisch Verhältnis Rußland demnach kürzeste Abwesenheit geschäftsmann zuließen Hunderttausend Russe ruhig Welt Herumfuhren Lauf Georg viele verändern Todesfall Georg Mutter erfolgen Georg alt Vater gemeinsam Wirtschaft leben Freund erfahren Beileid Brief Trockenheit ausdrücken Grund Trauer Ereignis Fremde unvorstellbar georg Geschäft groß Entschlossenheit anpacken Vater Lebzeite Mutter Geschäft Ansicht gelten lassen wirklich Tätigkeit hindern Vater Tod Mutter Geschäft arbeiten zurückhaltend spielen   sogar wahrscheinlich   glücklich zufälle wichtig Rolle jedenfalls Geschäft unerwartet entwickeln Personal verdoppeln Umsatz verfünffachen weit Fortschritt stehen zweifellos bevor
#
#  Freund Ahnung Veränderung letztenmal Beileidsbrief georg Auswanderung Rußland überreden Aussicht verbreiten Georg Geschäftszweig Petersburg bestehen Ziffer verschwindend Umfang georgs Geschäft annehmen Georg Lust Freund geschäftlich erfolgen schreiben nachträglich tun Merkwürdig anschein
#
#  beschränken georg Freund Bedeutungslose Vorfäll schreiben ruhig Sonntag nachdenken Erinnerung ungeordnet aufhäufen anderer Vorstellung ungestört lassen Freund Heimatstadt lang Zwischenzeit abgefunden geschehen Georg Freund Verlobung gleichgültig Mensch gleichgültig Mädchen dreimal ziemlich auseinanderliegend Brief anzeigen Freund georgs Absicht Merkwürdigkeit interessieren beginnen Georg schreiben dinge zugestehen Monat fräulein Frieda Brandenfeld Mädchen wohlhabend Familie verloben sprechen Braut Freund besonderer Korrespondenzverhältnis stehen Hochzeit freund kennen lernen stören antworten georg verstehen wahrscheinlich glauben zwingen schädigen fühlen beneid sicher unzufrieden unfähig Unzufriedenheit jemals beseitigen zurückfahren   weißen Heirat Weise erfahren verhindern lebensweise unwahrscheinlich Freund Georg Hättest verloben beide Schuld rasch atmend Küsse vorbrachen eigentlich kränken halten unverfänglich Freund schreiben hinnehmen Mensch herausschneiden Freundschaft geeignet
#
#  tatsächlich berichten Freund lang Brief Sonntagvormittag schreiben erfolgt Verlobung folgend Wort gut neuigkeit Schluß aufgespart fräulein Frieda Brandenfeld verloben Mädchen wohlhabend Familie abreise ansiedeln kennen dürftest gelegenheit finden Näheres brauen Mitzuteile genügen glücklich unser gegenseitig Verhältnis insofern ändern gewöhnlich freund glücklich Freund bekommsen brauen herzlich grüßen lassen nächstens schreiben aufrichtig freundin junggesell Bedeutung wissen halten vielerlei Besuch Hochzeit richtig Gelegenheit hindernisse Haufen werfen handeln Rücksicht Wohlmeinung Brief Hand georg Gesicht Fenster Zugekehrt Schreibtisch gesessen Bekannten vorübergeh Gasse grüßen abwesend lächeln antworten
#
#  stecken Brief Tasche zimmer quer Gang zimmer Vater Monat bestehen Nötigung verkehren Vater ständig Geschäft Mittagessen nehmen gleichzeitig Speisehaus abends versorgen belieben sitzen meistens georg häufig geschehen freund beisammen Braut besuchen weilch Zeitung gemeinsam Wohnzimmer
#
#  Georg staunen dunkel zimmer Vater sonnigen Vormittag Schatten werfen hoch Mauer jenseits schmal hofes erheben Vater sitzen Fenster Ecke verschieden Andenken selig Mutter ausgeschmücken lesen Zeitung seitlich Auge halten wodurch irgendein augenschwäch ausgleichen suchen Tisch stehen Rest Frühstück verzehren scheinen
#
#  ah Georg Vater entgegen schwer Schlafrock öffnen end umflatteren   Vater Riese Georg
#
#  unerträglich dunkel
#
#  dunkel antworten Vater
#
#  Fenster schließen
#
#
#
#  warm draußen Georg nachhang früh setzen
#
#  Vater räumen Frühstücksgeschirr stellen kaster
#
#  eigentlich sagen fahren georg fort Bewegung alt Mann verlieren folgen Petersburg Verlobung anzeigen ziehen Brief Tasche lassen zurückfallen wieso Petersburg fragen Vater
#
#  Freund Georg suchen Vater Auge   Geschäft denken breit sitzen Arm Brust Kreuzt
#
#  Freund Vater Betonung
#
#  weißen Vater Verlobung verschweigen Rücksichtnahme Grund weißen schwierig Mensch anderer Seite Verlobung erfahren Einsam lebensweise wahrscheinlich   hindern   erfahren
#
#  überlegen fragen Vater legen Zeitung Fensterbord Zeitung Brille Hand bedecken
#
#  überlegen Freund glücklich Verlobung Glück gezögeren anzeigen ehe Brief einwarf sagen
#
#  Georg Vater ziehen zahnlos Mund breite Hör Sache kommen beraten ehren Zweifel arg voll Wahrheit sagen dinge aufrühren hierher gehören Tod Teuer Mutter gewiß unschön dinge Vorgegang denken Geschäft entgehen verbergen   Annahme verbergen   kräftig Gedächtnis lassen Blick Sache erstens Ablauf Natur zweitens Tod unser mütterchens niederschlagen   Sache halten Brief bitte Georg täuschen Kleinigkeit Atem Wert täuschen Freund Petersburg
#
#  Georg stehen verlegen lassen Freund tausend Freund ersetzen Vater weißen glauben schonstn Alter verlangen Geschäft unentbehrlich weißen genau Geschäft Gesundheit bedrohen sperren lebensweise einführen Grund sitzen Dunkel Wohnzimmer Hättest schön Licht Nippst Frühstück ordentlich stärken
#
#  sitzen geschlossen Fenster Luft Vater Arzt holen Vorschrift folgen zimm wechseln vorderzimm ziehen hierher Veränderung übertragen legen Bett brauchst unbedingt ruh kommen ausziehn helfen sehn vorderzimm gehn legst vorläufig Bett vernünftig
#
#  Georg stehen knapp Vater Kopf struppig weiß Haar Brust sinken lassen
#
#  Georg Vater leise Bewegung
#
#  georg knien sofort Vater nieder Pupille müde Gesicht Vater übergroß Winkel Auge richten
#
#  Freund Petersburg spaßmach zurückhalten solltest Freund glauben
#
#  denk Vater Georg heben Vater Sessel ziehen schwach Dastand Schlafrock Freund Besuch erinneren hattest zweimal verleugnen zimmer sitzen Abneigung verstehn Freund Eigentümlichkeit unterhalten stolz zuhörtest nicktest Fragtest nachdenkst Mußt erinnern erzählen unglaublich Geschichte russisch Revolution z -- Geschäftsreise Kiew Tumult geistlich Balkon sehen breit blutkreuz flach Hand schneiden Hand erheben Menge Anrief Geschichte hie wiedererzählen
#
#  georg gelingen Vater niederzusetzen trikothos Leinenunterhose tragen Socke vorsichtig auszuziehn Anblick rein wäsche vorwürfen Vater vernachlässigen sicherlich Pflicht Wäschewechsel Vater wachen brauen Zukunft Vater einrichten ausdrücklich sprechen stillschweigend voraussetzen Vater alt Wohnung bleiben entschließen Bestimmtheit Vater künftig Haushalt mitzunehmen scheinen fast genau zusehen Pflege Vater bereiten spät
#
#  Arm tragen Vater Bett schrecklich Gefühl Paar Schritt Bett merken Brust Vater Uhrkette spielen Bett legen fest halten Uhrkette Bett scheinen decken ziehen Bettdecke Schulter unfreundlich Georg hinauf
#
#  erinnerst fragt Georg nicken aufmunternd
#
#  zudecken fragen Vater können nachschauen fuß bedeckt
#
#  fällen Bett Georg legen Deckzeug
#
#  zudecken fragen Vater scheinen Antwort aufzupassen ruhig zudecken
#
#  rufen Vater Antwort Frage stoßen werfen Decke Kraft Augenblick Flug entfalten stehen aufrecht Bett Hand halten Plafond Wolltest zudecken wissen früchtchen zudecken letzter Kraft zuviel kennen deinen Freund Sohn Herz betrügen glaubst weinen sperren Bureau stören Chef beschäftigen   falsch Briefch Rußland schreiben Vater glücklicherweise lehren Sohn durchschauen glauben hättest untergekriegen untergekriegen Hintern setzen rühren Herr Sohn heiraten entschließen Georg Schreckbild Vater petersburg Freund Vater plötzlich kennen Ergriff verlieren weit Rußland Türe leer ausgeraubt Geschäft trümmern Regale zerfetzten fallend gasarmen stehen wegfahren
#
#  schaun rufen Vater georg laufen fast zerstreut Bett fassen Stockt Mitte Weg
#
#  Röcke heben fing Vater Flöt Röcke heben Widerliche gans heben Darzustellen Hemd Oberschenkel narbe Kriegsjahr Röcke heben herangemacht Störung befriedigen Mutter Andenken schänden Freund verraten dein Vater Bett stecken rühren rühren stehen vollkommen frei werfen bein strahlen Einsicht
#
#  Georg stehen Winkel möglichst Vater lang weile fest entschließen vollkommen genau beobachten irgendwie umweg hinten herab überraschen können erinnern längst vergessen Entschluß vergessen kurz Faden Nadelöhr ziehen
#
#  Freund verraten rufen Vater Herbewegter Zeigefinger bekräftigen Vertreter Ort
#
#  komödiant georg rufen enthalten erkennen sofort Schaden Biß spät   Auge erstarren   zunge Schmerz einknicken
#
#  freilich Komödie spielen komöder Wort Trost bleiben alt verwitwet Vater Sag   Augenblick Antwort lebend Sohn   bleiben übrig Hinterzimmer verfolgen ungetreu Personal alt Knochen Sohn Jubel Welt schließen Geschäft vorbereiten überpurzelen Vergnügen Vater verschlossen Gesicht ehrenmann glaubst gelieben ausgingst
#
#  vorbeugen denken Georg fiele zerschmetterten Wort durchzischen Kopf Vater beugen fallen georg nähern erwarten erheben
#
#  bleib brauchen denken Kraft hierher Hältst bloß irren stark zurückweichen Mutter Kraft abgeben Freund herrlich verbinden Kundschaft Tasche
#
#  sogar Hemd taschen Georg glauben können Bemerkung Welt unmöglich Augenblick denken Immerfort vergessen
#
#  Häng brauen kommen entgegen fegen Seite weg weißen Georg grimassen glauben Vater nicken bloß Wahrheit beteuernd georgs Ecke unterhalten kamst Fragtest Freund Verlobung schreiben sollsten wissen dummer junge wissen schreiben vergessen Schreibzeug wegzunehmen wissen hundertmal Brief zerknüllen ungelesen linker Hand Brief lesen vorhalten arm schwingen Begeisterung Kopf wissen tausendmal rufen
#
#  zehntausendmal Georg Vater verlachen munde bekommen Wort toternst klingen
#
#  passen Frage kämest glaubst kümmern anderer glaubst les Zeitung werfen Georg Zeitungsblatt irgendwie Bett tragen alt Zeitung Georg unbekannt Name
#
#  zögern ehe reif Mutter müssen sterben Freudentag erleben Freund zugrunde Rußland gelb wegwerfen siehst stehen Auge
#
#  aufgelauert rufen Georg
#
#  mitleidig Vater nebenbei Wolltest wahrscheinlich sagen passen
#
#  lauter weißen wußtest unschuldig Kind warst eigentlich eigentlich warst teuflisch Mensch   wissen verurteilen Tod Ertrinken Georg fühlen zimmer jagen Schlag Vater auf Bett stürzen tragen Ohr Treppe Stufe schief fläch eilte überrumpelen Bedienerin begriffe heraufzugehen Wohnung Nacht aufzuräumen
#
#  Jesus rufen verdecken Schürze Gesicht Tor springen Fahrbahn Wasser treiben halten Geländer fest Hungriger Nahrung schwingen Ausgezeichnete Turner Jugendjahr Stolz Eltern
#
#  halten schwach werdend händen fest erspähen geländerstangen Autoomnibus Leichtigkeit Fall übertönen rufen leise lieb Eltern lieben lassen hinfallen Augenblick Brücke geradezu unendlich Verkehr

# %% [markdown]
# It worked! Let's repeat the process for the other texts (this time, without printing everything).

# %%
amerika = clean_text('data/Amerika.txt')

# %%
aphorisms = clean_text('data/Aphorismen.txt')

# %%
the_gallery = clean_text('data/Auf_der_Galerie.txt')

# %%
blumfeld = clean_text('data/Blumfeld,_ein_aelterer_Junggeselle.txt')

# %%
letter_to_father = clean_text('data/Brief_an_den_Vater.txt')

# %%
the_castle = clean_text('data/Das_Schloss.txt')

# %%
the_burrow = clean_text('data/Der_Bau.txt')

# %%
the_metamorphosis = clean_text('data/Die_Verwandlung.txt')

# %%
the_warden = clean_text('data/Der_Gruftwaechter.txt')

# %%
the_trial = clean_text('data/Der_Prozess.txt')

# %%
penal_colony = clean_text('data/In_der_Strafkolonie.txt')

# %% [markdown]
# Let's combine everything into one string so we can do some basic explorations:

# %%
all_texts = amerika + the_judgement + the_metamorphosis + penal_colony + the_trial + blumfeld + the_warden + aphorisms + letter_to_father + the_gallery + the_castle + the_burrow
#transform into list of words
list_words = all_texts.split()
print(list_words[0:30])
# Out:
# ['Heizer', 'sechzehnjährig', 'Karl', 'Roßmann', 'arm', 'Eltern', 'Amerika', 'schicken', 'dienstmädchen', 'verführen', 'Kind', 'bekommen', 'langsam', 'geworden', 'Schiff', 'Hafen', 'New', 'York', 'Einfuhr', 'erblicken', 'längst', 'beobachtet', 'Statue', 'Freiheitsgöttin', 'plötzlich', 'stark', 'geworden', 'Sonnenlicht', 'arm', 'Schwert']

# %%
#finding out the words Kafka most commonly uses
from collections import Counter

freqdist = Counter(list_words)

# %%
freqdist.most_common(40)
# Out:
# [('k', 2241),
#  ('Karl', 1201),
#  ('lassen', 610),
#  ('Herr', 597),
#  ('wissen', 589),
#  ('müssen', 583),
#  ('Hand', 567),
#  ('sehen', 553),
#  ('Tür', 516),
#  ('fragen', 510),
#  ('stehen', 501),
#  ('scheinen', 490),
#  ('Mann', 455),
#  ('fast', 405),
#  ('bleiben', 401),
#  ('gewiß', 400),
#  ('glauben', 389),
#  ('halten', 379),
#  ('Frieda', 379),
#  ('sagen', 371),
#  ('Frau', 367),
#  ('hören', 342),
#  ('Arbeit', 340),
#  ('rufen', 338),
#  ('Vater', 330),
#  ('liegen', 322),
#  ('denken', 311),
#  ('sprechen', 307),
#  ('Klamm', 303),
#  ('Auge', 293),
#  ('finden', 292),
#  ('kommen', 291),
#  ('Wort', 287),
#  ('sogar', 277),
#  ('zeigen', 274),
#  ('suchen', 255),
#  ('eigentlich', 250),
#  ('Sache', 249),
#  ('Gregor', 248),
#  ('wahrscheinlich', 247)]

# %%
#creating a wordcloud
from wordcloud import WordCloud

cleaned = ' '.join(list_words)
wordcloud = WordCloud().generate(cleaned)

# %%
fig, ax = plt.subplots(figsize=(16, 12))
ax.imshow(wordcloud, interpolation='nearest')
plt.tight_layout()

# %% [markdown]
# The most common words are mostly verbs like "let", "must", "seem", "know, "ask", "think", "see" indicate a focus on human actions and perceptions. Kafka's works often explore existential themes.
# The high frequency of the word "work" reflects how these themes are often intertwined with institutional or corporate settings.

# %% [markdown]
# #### Finding the number of unique words Kafka uses:

# %%
unique_words_set = set(list_words)
number_of_unique_words = len(unique_words_set)
print("Number of unique words:", number_of_unique_words)
# Out:
# Number of unique words: 19969

# %% [markdown]
# #### Finding bigrams using pointwise mutual information:

# %%
max_items = 30
freq_min_b = 10
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder2 = nltk.collocations.BigramCollocationFinder.from_words(list_words)
finder2.apply_word_filter(lambda w: w in string.punctuation)
finder2.apply_freq_filter(freq_min_b)
for a, b in finder2.nbest(bigram_measures.pmi, max_items):
    print(a, b)
# Out:
# Theater Oklahoma
# New York
# rechts links
# fräulein bürstn
# fügen hinzu
# fräulein Bürstner
# worum handeln
# fräulein Montag
# Fräulein Montag
# Fräulein Bürstner
# Soldat verurteilter
# gesenkt Kopf
# Frau grubach
# Anspruch nehmen
# paar Schritt
# Herr Pollunder
# Herr Green
# schütteln Kopf
# Ordnung bringen
# Herr Samsa
# Herr Pollunders
# halb Stunde
# Verbindung Schloß
# Frau oberköchin
# paar Stunde
# Herr Landvermesser
# paar Wort
# Herr Prokurist
# Gregor zimm
# jung Mann

# %% [markdown]
# #### Finding trigrams using pointwise mutual information:

# %%
max_items = 30
freq_min_t = 4
trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder3 = nltk.collocations.TrigramCollocationFinder.from_words(list_words)
finder3.apply_word_filter(lambda w: w in string.punctuation)
finder3.apply_freq_filter(freq_min_t)
for a, b, c in finder3.nbest(trigram_measures.pmi, max_items):
    print(a, b, c)
# Out:
# wissen worum handeln
# fragt Herr Pollunder
# paar Wort sprechen
# fahren k fort
# k Frau grubach
# Herr Pollunder Karl
# fassen Karl Hand
# Frau Wirtin k

# %% [markdown]
# A lot of the trigrams contain the singular letter "k" – this is since both of the longest texts in the corpus, "The Trial" and "The Castle" contain a main protagonist who is referred to as "K.". It's interesting that "wissen worum handeln" – likely from "wissen worum es sich handelt" which I would roughly translate to "know what something is about" – is at the top of the list.

# %% [markdown]
# ### Let's get into our research questions now. We will start by applying topic modelling to our entire corpus:

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import gensim
from gensim import corpora
from nltk.tokenize import word_tokenize


#organizing texts into documents
documents = [amerika, aphorisms, blumfeld, the_judgement, letter_to_father, the_castle, the_metamorphosis, penal_colony, the_trial, the_gallery, the_burrow, the_metamorphosis, the_warden]

#tokenizing the documents
tokenized_documents = [word_tokenize(doc.lower()) for doc in documents]

#creating dictionary
dictionary = corpora.Dictionary(tokenized_documents)

#filtering out low- and high-frequency words, which will improve topic quality, as described in this paper: https://ceur-ws.org/Vol-2723/long7.pdf
dictionary.filter_extremes(no_below=2, no_above=0.5)

#creating corpus
corpus = [dictionary.doc2bow(doc) for doc in tokenized_documents]

# %%
Lda = gensim.models.ldamodel.LdaModel

ldamodel = Lda(corpus, num_topics=5, id2word = dictionary, passes=50)

# %%
print(ldamodel.print_topics(num_topics=5, num_words=15))
# Out:
# [(0, '0.096*"karl" + 0.019*"robinson" + 0.011*"onkel" + 0.007*"koffer" + 0.005*"hotel" + 0.005*"straße" + 0.005*"geld" + 0.004*"student" + 0.003*"polizeimann" + 0.003*"balkon" + 0.003*"fragt" + 0.003*"photographie" + 0.002*"kamerad" + 0.002*"schiff" + 0.002*"automobil"'), (1, '0.094*"k" + 0.018*"frieda" + 0.010*"advokat" + 0.007*"schloß" + 0.007*"ks" + 0.007*"gehilfe" + 0.005*"beamter" + 0.005*"prozeß" + 0.005*"fräulein" + 0.005*"lehrer" + 0.004*"gericht" + 0.004*"wirt" + 0.004*"onkel" + 0.003*"kaufmann" + 0.003*"partei"'), (2, '0.020*"wächter" + 0.006*"warst" + 0.005*"hättest" + 0.005*"hattest" + 0.004*"heiraten" + 0.003*"erziehung" + 0.003*"schuldbewußtsein" + 0.003*"hoheit" + 0.003*"weißen" + 0.003*"jeher" + 0.003*"person" + 0.003*"konntest" + 0.003*"heirat" + 0.003*"geistig" + 0.002*"hinsicht"'), (3, '0.059*"gregor" + 0.024*"schwester" + 0.010*"prokurist" + 0.009*"bau" + 0.007*"samsa" + 0.007*"bedienerin" + 0.006*"eltern" + 0.005*"praktikant" + 0.004*"kanapee" + 0.004*"schlüssel" + 0.004*"zimmerherrer" + 0.003*"gret" + 0.003*"möbel" + 0.003*"kasten" + 0.003*"wohnzimmer"'), (4, '0.038*"offizier" + 0.035*"reisende" + 0.021*"kommandant" + 0.020*"soldat" + 0.010*"reisend" + 0.010*"apparat" + 0.010*"maschine" + 0.008*"zeichner" + 0.007*"verfahren" + 0.004*"kette" + 0.004*"riemen" + 0.003*"kolonie" + 0.003*"anhänger" + 0.003*"schrift" + 0.002*"einladung"')]

# %% [markdown]
# Let's try interpreting these topics:
#
# - 0: This topic includes words like "Koffer" ("Suitcase"), "Hotel", "Schiff" ("ship") and seems to focus on traveling/adventure. A lot of these words are likely from the novel "Amerika".
# - 1: This topic seems to focus on judicial themes: "Advokat" (Lawyer), "Prozeß" ("Trial"), "Gericht" ("court") etc. are included in this topic. This makes sense since several of Kafka's works (The Trial, In The Penal Colony) deal with these themes.
# - 2: Here we see words like "heiraten" ("to marry"), "erziehung" ("education" or "upbringing"), "Schuldbewußtsein" ("sense of guilt"),  indicating a focus on personal relationships and or moral dilemmas.
# - 3: Topic 3 contains words like "Eltern" ("parents"), "Kanapee" ("Sofa"), "Schwester" ("sister"), "Möbel" ("furniture") etc., indicating a domestic setting and family dynamics.
# - 4: : Pretty much all of these words seem to come from the story "In the Penal Colony": "Reisender" ("Traveler"), "Soldat" (Soldier), "Apparat" ("Machine") and so on.
#
# Overall, the topics show common themes in Kafka's writing, but the topics correspond more to the individual texts than giving insight into the corpus as a whole. This is possibly due to
# - the corpus being quite small
# - longer texts dominating the topics.
#
# We can't remedy these issues in the scope of this project, but on a positive note, the topic quality seems good – the topics don't consist of cohesion elements as is often an issue with literary texts, but are actually meaningful and interpretable. We can assume that when applied to a larger corpus, topic modelling could be quite useful.

# %% [markdown]
# ### Let's try doing a Sentiment Analysis on some of these texts!

# %% [markdown]
# We will be focusing on the following works:
# - "Amerika" ("Amerika", written between 1911-1914),
# - "Die Verwandlung" ("The Metamorphosis", written 1912),
# - "In der Strafkolonie" ("In the Penal Colony", written 1914),
# - "Der Prozess" ("The Trial", written 1914-1915),
# - "Das Schloss" ("The Castle", written 1922)
# - "Der Bau" ("The Burrow", written 1923-1924)

# %% [markdown]
# To do this, we will need to re-import our text files and clean them while this time leaving the sentences intact. Let's modify the code from before:

# %%
with open('data/Das_Schloss.txt', 'r', encoding='ISO-8859-1') as file:
    castle_sent = file.read()

# %%
with open('data/Der_Prozess.txt', 'r', encoding='ISO-8859-1') as file:
    trial_sent = file.read()

# %%
with open('data/Amerika.txt', 'r', encoding='ISO-8859-1') as file:
    amerika_sent = file.read()

# %%
with open('data/Die_Verwandlung.txt', 'r', encoding='ISO-8859-1') as file:
    metamorphosis_sent = file.read()

# %%
from textblob import TextBlob

#creating textblob object
blob = TextBlob(castle_sent)

#tokenizing
blob = TextBlob(text)
sentences = blob.sentences

#creating list to store polarity scores
polarity_scores = []

# analyzing sentiment for each sentence and collecting polarity scores
for sentence in sentences:
    score = sentence.sentiment.polarity
    polarity_scores.append(score)

# %%
#calculating average polarity
average_polarity = sum(polarity_scores) / len(polarity_scores)

print(f"Average Sentiment Polarity: {average_polarity}")
# Out:
# Average Sentiment Polarity: 0.0

# %%
from textblob import TextBlob

blob = TextBlob(trial_sent)

blob = TextBlob(text)
sentences = blob.sentences

polarity_scores = []

for sentence in sentences:
    score = sentence.sentiment.polarity
    polarity_scores.append(score)

# %%
average_polarity = sum(polarity_scores) / len(polarity_scores)

print(f"Average Sentiment Polarity: {average_polarity}")
# Out:
# Average Sentiment Polarity: 0.0

# %% [markdown]
# It seems like applying Sentiment Analysis to our texts with textblob isn't giving us useful results. Let's try it a bit differently:

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/Clara/nltk_data...
# True

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk import sent_tokenize

#intializing vader analyzer
sia = SentimentIntensityAnalyzer()

#defining function to apply vader to texts
def analyze_sentiments_from_file(file_path):
    neg_scores = []
    neu_scores = []
    pos_scores = []
    compound_scores = []

    with open(file_path, 'r', encoding='ISO-8859-1') as file:
        text = file.read()  #reading text from file

        #tokenizing into sentences
        sentences = nltk.sent_tokenize(text, language='german')

        #analyzing and collecting sentiment scores for each sentence
        for sentence in sentences:
            scores = sia.polarity_scores(sentence)
            neg_scores.append(scores['neg'])
            neu_scores.append(scores['neu'])
            pos_scores.append(scores['pos'])
            compound_scores.append(scores['compound'])

    #calculating overall average sentiment scores
    overall_avg_neg = sum(neg_scores) / len(neg_scores)
    overall_avg_neu = sum(neu_scores) / len(neu_scores)
    overall_avg_pos = sum(pos_scores) / len(pos_scores)
    overall_avg_compound = sum(compound_scores) / len(compound_scores)

    return {
        'avg_neg': overall_avg_neg,
        'avg_neu': overall_avg_neu,
        'avg_pos': overall_avg_pos,
        'avg_compound': overall_avg_compound
    }

# %% [markdown]
# #### Let's apply the function to our texts:

# %%
analyze_sentiments_from_file('data/Amerika.txt')
# Out:
# {'avg_neg': 0.09751563845050219,
#  'avg_neu': 0.8974774748923965,
#  'avg_pos': 0.0050051649928263995,
#  'avg_compound': -0.33770648493543176}

# %%
analyze_sentiments_from_file('data/Die_Verwandlung.txt')
# Out:
# {'avg_neg': 0.14063414634146343,
#  'avg_neu': 0.8569131097560972,
#  'avg_pos': 0.002446646341463414,
#  'avg_compound': -0.4841815548780489}

# %%
analyze_sentiments_from_file('data/In_der_Strafkolonie.txt')
# Out:
# {'avg_neg': 0.12316204690831557,
#  'avg_neu': 0.8740383795309156,
#  'avg_pos': 0.0028038379530916837,
#  'avg_compound': -0.3608733475479751}

# %%
analyze_sentiments_from_file('data/Der_Prozess.txt')
# Out:
# {'avg_neg': 0.10229911323328784,
#  'avg_neu': 0.8926995225102322,
#  'avg_pos': 0.005002046384720325,
#  'avg_compound': -0.3304536834924884}

# %%
analyze_sentiments_from_file('data/Das_Schloss.txt')
# Out:
# {'avg_neg': 0.09923983842464058,
#  'avg_neu': 0.8986119666750801,
#  'avg_pos': 0.0021492047462761932,
#  'avg_compound': -0.35149747538500203}

# %%
analyze_sentiments_from_file('data/Der_Bau.txt')
# Out:
# {'avg_neg': 0.07721361502347421,
#  'avg_neu': 0.9221361502347416,
#  'avg_pos': 0.0006525821596244132,
#  'avg_compound': -0.3169427230046953}

# %% [markdown]
# #### Let's visualize these scores in a plot!

# %%
texts = ['Amerika', 'Metamorphosis', 'In The Penal Colony', 'The Trial', 'The Castle', 'The Burrow']
neg_scores = [0.09751563845050219,0.14063414634146343, 0.12316204690831557, 0.10229911323328784,0.09923983842464058, 0.07721361502347421]
neu_scores = [0.8974774748923965,0.8569131097560972,0.8740383795309156,0.8926995225102322,0.8986119666750801, 0.9221361502347416 ]
pos_scores = [0.0050051649928263995, 0.002446646341463414, 0.0028038379530916837, 0.005002046384720325, 0.0021492047462761932, 0.0006525821596244132]
compound_scores = [-0.33770648493543176, -0.4841815548780489, -0.3608733475479751, -0.3304536834924884, -0.35149747538500203,  -0.3169427230046953]

plt.figure(figsize=(10, 6))

indices = range(len(texts))
width = 0.2

#plotting the bars for each score
plt.bar(indices, neg_scores, width=width, label='Negative', color='red')
plt.bar([i + width for i in indices], neu_scores, width=width, label='Neutral', color='blue')
plt.bar([i + width * 2 for i in indices], pos_scores, width=width, label='Positive', color='green')
plt.bar([i + width * 3 for i in indices], compound_scores, width=width, label='Compound', color='purple')

#labels and title
plt.xlabel('<-1911-1924->')
plt.ylabel('Scores')
plt.title('Sentiment Analysis Scores by Text')

#adding xticks
plt.xticks([i + width * 1.5 for i in indices], texts)

#legend
plt.legend()

#displaying plot
plt.tight_layout()
plt.show()

# %% [markdown]
# All of the texts have extremely low positive scores, and show a slight negative sentiment, with "The Metamorphosis" having the highest negative score. Overall, all the compound scores are negative, which is not surprising considering Kafka's often somber writing and themes. There's no trend to be seen over time. It's important to consider that literature is complex and might convey sentiment in a way that can not be measured with these methods.

# %% [markdown]
# Out of curiosity, I wanted to see if Kafka's letters to Milena – non-fictional "love letters", after all – would show a similar sentiment. They were not part of the corpus I used, but I found a pdf file that I will use to extract the text data from:

# %%
# !pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Obtaining dependency information for pdfplumber from https://files.pythonhosted.org/packages/f8/d3/f58c2d5d86a585e438c6708f568eca79e7c4e6ee3d5210cf8b31d38cb021/pdfplumber-0.10.3-py3-none-any.whl.metadata
#   Downloading pdfplumber-0.10.3-py3-none-any.whl.metadata (38 kB)
# Collecting pdfminer.six==20221105 (from pdfplumber)
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 866.2 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: Pillow>=9.1 in /Users/Clara/anaconda3/lib/python3.11/site-packages (from pdfplumber) (9.4.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Obtaining dependency information for pypdfium2>=4.18.0 from https://files.pythonhosted.org/packages/5e/55/7a85d92b115bb530797cd2ac5c11b905acbfd1d71cea88207eb276d1506a/pypdfium2-4.26.0-py3-none-macosx_10_13_x86_64.whl.metadata
#   Downloading pypdfium2-4.26.0-py3-none-macosx_10_13_x86_64.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/Clara/anaconda3/lib/python3.11/site-packages (from pdfminer.six==20221105->pdfplumber) (2.0.4)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/Clara/anaconda3/lib/python3.11/site-packages (from pdfminer.six==20221105->pdfplumber) (41.0.3)
# Requirement already satisfied: cffi>=1.12 in /Users/Clara/anaconda3/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (1.15.1)
# Requirement already satisfied: pycparser in /Users/Clara/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (2.21)
# Downloading pdfplumber-0.10.3-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 kB 1.6 MB/s eta 0:00:00
# Downloading pypdfium2-4.26.0-py3-none-macosx_10_13_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 630.2 kB/s eta 0:00:0000:0100:01
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
#   Attempting uninstall: pdfminer.six
#     Found existing installation: pdfminer.six 20191110
#     Uninstalling pdfminer.six-20191110:
#       Successfully uninstalled pdfminer.six-20191110
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# textract 1.6.5 requires pdfminer.six==20191110, but you have pdfminer-six 20221105 which is incompatible.
# Successfully installed pdfminer.six-20221105 pdfplumber-0.10.3 pypdfium2-4.26.0

# %%
#modifying code from before:
import pdfplumber

#defining function
def analyze_sentiments_from_pdf(pdf_file_path):
    neg_scores = []
    neu_scores = []
    pos_scores = []
    compound_scores = []

    #extracting text from pdf
    with pdfplumber.open(pdf_file_path) as pdf:
        text = ''
        for page in pdf.pages:
            text += page.extract_text()

        sentences = nltk.sent_tokenize(text, language='german')

        for sentence in sentences:
            scores = sia.polarity_scores(sentence)
            neg_scores.append(scores['neg'])
            neu_scores.append(scores['neu'])
            pos_scores.append(scores['pos'])
            compound_scores.append(scores['compound'])

    overall_avg_neg = sum(neg_scores) / len(neg_scores)
    overall_avg_neu = sum(neu_scores) / len(neu_scores)
    overall_avg_pos = sum(pos_scores) / len(pos_scores)
    overall_avg_compound = sum(compound_scores) / len(compound_scores)

    return {
        'avg_neg': overall_avg_neg,
        'avg_neu': overall_avg_neu,
        'avg_pos': overall_avg_pos,
        'avg_compound': overall_avg_compound
    }


pdf_file_path = 'data/BriefeAnMilena.pdf'
sentiment_scores = analyze_sentiments_from_pdf(pdf_file_path)
print(sentiment_scores)
# Out:
# {'avg_neg': 0.07418833283979863, 'avg_neu': 0.9228658572697668, 'avg_pos': 0.0023532721350310926, 'avg_compound': -0.24044006514657448}

# %% [markdown]
# #### Lets's add this to the plot!

# %%
texts = ['Amerika', 'Metamorphosis', 'In The Penal Colony', 'The Trial', 'The Castle', 'The Burrow', 'Letters to Milena']
neg_scores = [0.09751563845050219,0.14063414634146343, 0.12316204690831557, 0.10229911323328784,0.09923983842464058, 0.07721361502347421, 0.07418833283979863]
neu_scores = [0.8974774748923965,0.8569131097560972,0.8740383795309156,0.8926995225102322,0.8986119666750801, 0.9221361502347416, 0.9228658572697668 ]
pos_scores = [0.0050051649928263995, 0.002446646341463414, 0.0028038379530916837, 0.005002046384720325, 0.0021492047462761932, 0.0006525821596244132,0.0023532721350310926 ]
compound_scores = [-0.33770648493543176, -0.4841815548780489, -0.3608733475479751, -0.3304536834924884, -0.35149747538500203,  -0.3169427230046953, -0.24044006514657448]

plt.figure(figsize=(10, 6))

indices = range(len(texts))
width = 0.2

#plotting the bars for each score
plt.bar(indices, neg_scores, width=width, label='Negative', color='red')
plt.bar([i + width for i in indices], neu_scores, width=width, label='Neutral', color='blue')
plt.bar([i + width * 2 for i in indices], pos_scores, width=width, label='Positive', color='green')
plt.bar([i + width * 3 for i in indices], compound_scores, width=width, label='Compound', color='purple')

#labels and title
plt.xlabel('Texts')
plt.ylabel('Scores')
plt.title('Sentiment Analysis Scores by Text')

#adding xticks
plt.xticks([i + width * 1.5 for i in indices], texts)

#legend
plt.legend()

#displaying plot
plt.tight_layout()
plt.show()
